# %%
from table_evaluator import load_data, TableEvaluator
# Out:
# IPython not installed.

# %%
real, fake = load_data('data/clean_data.csv', 'data/ctgan_data.csv')

# %%
cat_cols = ['day_part_y','message','user_id','serverTimestamp','timestamp']

# %%
table_evaluator = TableEvaluator(real, fake, cat_cols=cat_cols)

# %%
table_evaluator.visual_evaluation()
# Out:
# c:\Users\nbasa\AppData\Local\Programs\Python\Python311\Lib\site-packages\table_evaluator\table_evaluator.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(axes[i].get_xticklabels(), rotation='vertical')
# c:\Users\nbasa\AppData\Local\Programs\Python\Python311\Lib\site-packages\table_evaluator\table_evaluator.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(axes[i].get_xticklabels(), rotation='vertical')
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# File c:\Users\nbasa\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_kde.py:226, in __init__(self, dataset, bw_method, weights)
#     224 except linalg.LinAlgError as e:
# ...

# %%
table_evaluator.evaluate(target_col='message')
# Out:
# c:\Users\nbasa\AppData\Local\Programs\Python\Python311\Lib\site-packages\dython\nominal.py:293: RuntimeWarning: Rounded eta = 1.0000000000000002 to 1. This is probably due to floating point precision issues.
#   warnings.warn(
# c:\Users\nbasa\AppData\Local\Programs\Python\Python311\Lib\site-packages\table_evaluator\metrics.py:87: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr[column], _ = ss.pearsonr(dataset_a[column].sort_values(), dataset_b[column].sort_values())
# c:\Users\nbasa\AppData\Local\Programs\Python\Python311\Lib\site-packages\dython\nominal.py:293: RuntimeWarning: Rounded eta = 1.0000000000000002 to 1. This is probably due to floating point precision issues.
#   warnings.warn(
# c:\Users\nbasa\AppData\Local\Programs\Python\Python311\Lib\site-packages\dython\nominal.py:293: RuntimeWarning: Rounded eta = 1.0000000000000002 to 1. This is probably due to floating point precision issues.
#   warnings.warn(
# ...
